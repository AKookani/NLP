# %% [markdown]
# <a href="https://colab.research.google.com/github/AKookani/NLP/blob/main/Q6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Naive Bayes
# You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * we used the ratio of probabilities between positive and negative sentiments.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %%
#from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the twitter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# # Part 1: Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet()` that does this for you.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.stem import PorterStemmer

def process_tweet(tweet):
    """
    Cleans the tweet by removing noise and applies stemming.

    Arguments:
    tweet -- a string containing a tweet

    Returns:
    words -- a list of cleaned and stemmed words from the tweet
    """
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words('english'))
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

    # Tokenize the tweet
    tokens = tokenizer.tokenize(tweet)

    # Remove noise: punctuation, stopwords, and non-alphabetic words
    words = [stemmer.stem(word) for word in tokens
             if word not in stop_words and word not in string.punctuation and word.isalpha()]

    return words

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['rt', 'hello', 'great', 'day']

# %% [markdown]
# ## Part 1.1 Implementing your helper functions
#
# To help train your naive bayes model, you will need to build a dictionary where the keys are a (word, label) tuple and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a `lookup()` helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2
#     ("happi", 1) : 1
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# #### Instructions
# Create a function `count_tweets()` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            pair = (word, y)
            result[pair] = result.get(pair, 0) + 1

    return result

# %%
# Testing your function


result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# # Part 2: Train your model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets()` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses

freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# #### Instructions
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$ and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of your Naive Bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    # Calculate the number of unique words in the vocabulary
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    # Calculate the number of positive and negative words
    N_pos = sum([freqs[(word, 1)] for word in vocab if (word, 1) in freqs])
    N_neg = sum([freqs[(word, 0)] for word in vocab if (word, 0) in freqs])

    # Calculate the number of positive and negative tweets
    D_pos = len([y for y in train_y if y == 1])
    D_neg = len([y for y in train_y if y == 0])

    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg)

    # Calculate loglikelihood for each word
    for word in vocab:
        # Get the positive and negative frequency of the word
        freq_pos = freqs.get((word, 1), 0)
        freq_neg = freqs.get((word, 0), 0)

        # Calculate the probability of the word being positive or negative
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        # Calculate the loglikelihood of the word
        loglikelihood[word] = np.log(p_w_pos) - np.log(p_w_neg)

    return logprior, loglikelihood

# %%
# Build the freqs dictionary for training
freqs = count_tweets({}, train_x, train_y)

# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

# Print the results
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 7416

# %% [markdown]
# # Part 3: Test your naive bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# #### Implement `naive_bayes_predict`
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)
    '''
    # Process the tweet to extract words
    words = process_tweet(tweet)

    # Initialize probability with the logprior
    p = logprior

    # Add loglikelihood of each word in the tweet
    for word in words:
        if word in loglikelihood:
            p += loglikelihood[word]

    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Experiment with your own tweet.
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.48008593023508

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.57
# - The sentiment is positive.

# %% [markdown]
# #### Implement test_naive_bayes
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    # Initialize a counter for correct predictions
    correct_predictions = 0

    # Loop through each tweet and its corresponding label
    for tweet, label in zip(test_x, test_y):
        # Predict the sentiment of the tweet
        prediction = naive_bayes_predict(tweet, logprior, loglikelihood)

        # Convert prediction to binary: 1 if positive, else 0
        predicted_label = 1 if prediction > 0 else 0

        # Compare predicted label with the true label
        if predicted_label == label:
            correct_predictions += 1

    # Calculate accuracy
    accuracy = correct_predictions / len(test_x)

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.7460

# %% [markdown]
# **Expected Accuracy**:
#
# 0.9940

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.09
# I am bad -> -1.25
# this movie should have been great. -> 2.09
# great -> 2.12
# great great -> 4.23
# great great great -> 6.35
# great great great great -> 8.46

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.15
# - I am bad -> -1.29
# - this movie should have been great. -> 2.14
# - great -> 2.14
# - great great -> 4.28
# - great great great -> 6.41
# - great great great great -> 8.55

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# -1.2477668981633103

# %% [markdown]
# # Part 4: Filter words by Ratio of positive to negative counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# #### Implement `get_ratio()`
# - Given the `freqs` dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup()` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words
        word: string to lookup

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}

    # Get the positive and negative counts of the word
    pos_neg_ratio['positive'] = freqs.get((word, 1), 0)
    pos_neg_ratio['negative'] = freqs.get((word, 0), 0)

    # Calculate the ratio (avoid division by zero)
    if pos_neg_ratio['negative'] == 0:
        pos_neg_ratio['ratio'] = float('inf')
    else:
        pos_neg_ratio['ratio'] = pos_neg_ratio['positive'] / pos_neg_ratio['negative']

    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 157, 'negative': 18, 'ratio': 8.722222222222221}

# %% [markdown]
# #### Implement `get_words_by_threshold(freqs,label,threshold)`
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio()` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append a dictionary to a list, where the key is the word, and the dictionary is the dictionary `pos_neg_ratio` that is returned by the `get_ratio()` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.5}
# }
# ```

# %%
def get_words_by_threshold(freqs, label, threshold):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_set: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    for word in set([pair[0] for pair in freqs.keys()]):
        pos_neg_ratio = get_ratio(freqs, word)

        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
            word_list[word] = pos_neg_ratio
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
            word_list[word] = pos_neg_ratio

    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {'deepxcap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'koe': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mumma': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'netflix': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'keeno': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'leno': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nein': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'rodwel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'toler': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'creed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'solvo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ic': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'biphob': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'walay': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sched': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'walao': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'linguist': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kaussi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'assassin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'eve': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pray': {'positive': 0, 'negative': 12, 'ratio': 0.0},
#  'sirf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'talaga': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'glitch': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'maverickgam': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'davao': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sophi': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'anybodi': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'negoti': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'foof': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shaaa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'icu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'odoo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'pixel': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'noooo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'collabor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'despair': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'beardi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'agov': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'etienn': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'faint': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'wheel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ik': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'krispi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'scarf': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'when': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'masaan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'habhab': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dovey': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'exclud': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'sue': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noggin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'meter': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'senight': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'carva': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gamestomp': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shape': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hmph': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ampsha': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ov': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'haiss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'journo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'harlo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dh': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'buckl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'novemb': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kennel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ghantay': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'speed': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'inuyasha': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'beyt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hueee': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tseba': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gunna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noseble': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'papertown': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'schedul': {'positive': 0, 'negative': 7, 'ratio': 0.0},
#  'vava': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'elsa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yahoo': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'je': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'yield': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'happpi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'polaroid': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gahd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'warrior': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'athabasca': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'peanut': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'robinhood': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'liverpool': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'monkey': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ano': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'encor': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'anythin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'stella': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'audit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'saddest': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'suspems': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hopper': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'maldiv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'heed': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'unhealthi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mash': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'lapar': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sj': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'truli': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'nowww': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'amb': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cr': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'minkyuk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zikra': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'leas': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'monash': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'twelvyy': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'inconsider': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'invalid': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hernia': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'tgk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fiver': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bodo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ipod': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'endlessli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'ming': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pup': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'brook': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'noo': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'trespass': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'iwantin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'everday': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rub': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'baggag': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'pregnanc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sunggyu': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'mmmm': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'fluent': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mehendi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'poop': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bethesda': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'motor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'caramello': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'tub': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'que': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'raiz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gut': {'positive': 0, 'negative': 9, 'ratio': 0.0},
#  'buri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pll': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'extern': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'dunt': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cali': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shite': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'donno': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cori': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'exit': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'photocard': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'te': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'paramed': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'giriboy': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'japan': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'delph': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'progress': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'laribuggi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tacki': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vandag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'jfc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'influenti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'freedom': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'teas': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'trouser': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bummer': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'shiver': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'polka': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bi': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'xpress': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'frustrat': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'groceri': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'zone': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'daal': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'cope': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'lego': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'toll': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'prepaid': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'saaad': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'bruno': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gwss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sissi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'aigooo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'realist': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'skyfal': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'shaa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'saklap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'protein': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'stu': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'titan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'squishi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tito': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'budget': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'honesti': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'satya': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sarajevo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bowel': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pon': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'glacier': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pale': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'takeov': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gidi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'motiv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'sudden': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'blush': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'harap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'swipe': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'swell': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'sandwich': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'rhisfor': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rattl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'brisban': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hoya': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'willi': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'playstat': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'ell': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'carriag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'georgesampson': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'chalet': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'theo': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'agh': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'spece': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'aaag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'swap': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'suckmejimin': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'erica': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hasya': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'across': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'isra': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'gintama': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mee': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pyaaz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kimaaani': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'buttsex': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'naa': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'cupcak': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'churro': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'specif': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'imposs': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'lure': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'duti': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'repackag': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'mixtur': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'persuad': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'stab': {'positive': 0, 'negative': 3, 'ratio': 0.0},
#  'christ': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'charad': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'imiss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rtd': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'msc': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rihanna': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'soak': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'orphan': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'tsktsk': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'snot': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'olivia': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'valentin': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'delet': {'positive': 0, 'negative': 5, 'ratio': 0.0},
#  'uca': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'buset': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'grumpi': {'positive': 0, 'negative': 4, 'ratio': 0.0},
#  'ugh': {'positive': 1, 'negative': 22, 'ratio': 0.045454545454545456},
#  'racial': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'comparison': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'happier': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'angek': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rome': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'neng': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'muller': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dheena': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'dandia': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'pinkfinit': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'akong': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'reynoldsgrl': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'reaalli': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'nia': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'vv': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'kgola': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'hz': {'positive': 0, 'negative': 2, 'ratio': 0.0},
#  'bbz': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'rash': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'monteith': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'crosss': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'bald': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'brake': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  'remast': {'positive': 0, 'negative': 1, 'ratio': 0.0},
#  
{'positive': 1, 'negative': 0, 'ratio': inf},
#  'tara': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'yeheyi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hatr': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'argu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'barkin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'equal': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'proverb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jazz': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'paysafecard': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hood': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ulit': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'mono': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'uniform': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'jute': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'resto': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'caro': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'encompass': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'doug': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'gastronomi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'onkey': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'triathlet': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'soda': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'deti': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'seungyeon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lmaooo': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'peep': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'ji': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'warmup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yoona': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'surreal': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'upper': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'unlock': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'catho': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arr': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gibran': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'veggi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thick': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ideal': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 20.5},
#  'intellectu': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'phl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'yeeaayi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'monster': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fahrenheit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'paddock': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'meri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'color': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'ig': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'earl': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'genr': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tidi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'deaf': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'lwwf': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fridg': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'blog': {'positive': 26, 'negative': 0, 'ratio': inf},
#  'rofl': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'suav': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'verg': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'setup': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bing': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'mice': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'sumedh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'knit': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'durood': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'solar': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'savag': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'obv': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'thark': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'peru': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'cola': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bitchfac': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'champion': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'squat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'advaddict': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'gibanica': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'beautiful': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'muahhh': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'stamina': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lolz': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'meme': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'queri': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dragon': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'xoxo': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'gal': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'bulat': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'billi': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'coaster': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'keepin': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'explor': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'disagre': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'hihihi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'herb': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'chibi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'attract': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'consumer': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'suffer': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'tent': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'presid': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'meaningless': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'rescoop': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'drew': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'gandhi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'mandela': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fron': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'dampen': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'luff': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ga': {'positive': 3, 'negative': 0, 'ratio': inf},
#  'yummmyyi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'process': {'positive': 4, 'negative': 0, 'ratio': inf},
#  'anticip': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'nom': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'welcom': {'positive': 54, 'negative': 5, 'ratio': 10.8},
#  'pun': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'fahad': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'suitcas': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'aur': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'penthous': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'arma': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'tower': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'bapu': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'garbi': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'ब': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'lemon': {'positive': 2, 'negative': 0, 'ratio': inf},
#  'oper': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'separ': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'timezon': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'leia': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'litey': {'positive': 1, 'negative': 0, 'ratio': inf},
#  'kha': {'positive': 1, 'negative': 0, 'ratio': inf},
#  ...}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like 'glad', 'community', and 'arrives' tend to be found in the positive tweets.

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the misclassifications happened? Were there any assumptions made by the naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'bro u wan cut hair anot ur hair long liao bo sinc ord liao take easi lor treat save leav longer bro lol sibei xialan'
# 1	0.00	b'stuck centr right clown right joker left'
# 1	0.00	b'work'
# 1	0.00	b'hahahahahahahahahahahahahaha die liter front like'
# 1	0.00	b'awak'
# 1	0.00	b'f'
# 1	0.00	b'lyka followback'
# 1	0.00	b'thank ye hope work miss'
# 1	0.00	b'awkward moment name akarshan end stay singl'
# 1	0.00	b'highfiv probabl ahead sinc less artsi verbal'
# 1	0.00	b'bae'
# 1	0.00	b'kid kaaa'
# 1	0.00	b'anchor sea'
# 1	0.00	b'bore everyth'
# 1	0.00	b'mean aamir khan one'
# 1	0.00	b'want'
# 1	0.00	b'truli later move know queen bee upward bound'
# 1	0.00	b'actual need stop tweet drive'
# 1	0.00	b'betcha dumb butt'
# 1	0.00	b'kik qualki'
# 1	0.00	b'wish kid'
# 1	0.00	b'sure would good thing bottom dare say miss b im gonna stubborn mouth soap'
# 1	0.00	b'ye car'
# 1	0.00	b'yeah kinda feel like warm butter'
# 1	0.00	b''
# 1	0.00	b'whenev sister see cri text ask im okay aw someon care'
# 1	0.00	b'take care'
# 1	0.00	b'glyon'
# 1	0.00	b'initi pm order'
# 1	0.00	b'know dumb think johnni rock u seen utub mad respect'
# 1	0.00	b'sorri loss hope goe well'
# 1	0.00	b'combin three add bit asian u got truli'
# 1	0.00	b'got call end pigeon home safe definit worth contact'
# 1	0.00	b'saturday'
# 1	0.00	b'type wors thing good'
# 1	0.00	b'soon'
# 1	0.00	b'ftw'
# 1	0.00	b'ah see song prefer take maman'
# 1	0.00	b'like hurt feel anyth right'
# 1	0.00	b'check new van outsid olymp park anniversari game'
# 1	0.00	b'everi year august get fever dunno'
# 1	0.00	b'yeah classi look seen peopl attach sort life save equip bed fix'
# 1	0.00	b'trend follow bobbl link'
# 1	0.00	b'next year sure though girl piss'
# 1	0.00	b'im tri l english patch psp'
# 1	0.00	b'first leg magictrikband tour go well'
# 1	0.00	b'whatsapp roommat want anyth pari french man lol sure head park grab one'
# 1	0.00	b'woke feel incred sick idk caus drank starbuck last night reaction med'
# 1	0.00	b'call night go sleep'
# 1	0.00	b'wat'
# 1	0.00	b'safe'
# 1	0.00	b'sombrero high okay lost'
# 1	0.00	b'die actual pretti entertain'
# 1	0.00	b'wow realli hate'
# 1	0.00	b'want protect relationship other talk ppl need know awesom'
# 1	0.00	b'oh dang zen look outsid space neat'
# 1	0.00	b'hiya afraid alreadi pick rider year look next year'
# 1	0.00	b'lucki'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather'
# 1	0.00	b'say someth give sorri get'
# 1	0.00	b'gonna anoth one final'
# 1	0.00	b'uhc box larg scale one network server'
# 1	0.00	b'ever areal lunch dinner'
# 1	0.00	b'magnific'
# 1	0.00	b'yeah tri look x'
# 1	0.00	b'ye omg lile tid tmi'
# 1	0.00	b'cute boy jule'
# 1	0.00	b'oh shoot well watch'
# 1	0.00	b'far lfc fan make expert spot mental weak lack consist'
# 1	0.00	b'tope'
# 1	0.00	b'hey fam vote alreadi gotta win boy'
# 1	0.00	b'ha almost gave fuck boy trash wast time sure'
# 1	0.00	b'noth much need grow'
# 1	0.00	b'ask end friend'
# 1	0.00	b'return'
# 1	0.00	b'catch fall fall ontrack'
# 1	0.00	b'guess show german also subtitl'
# 1	0.00	b'pinter'
# 1	0.00	b'cute'
# 1	0.00	b'fabul time miss xx'
# 1	0.00	b'never show much'
# 1	0.00	b''
# 1	0.00	b'knew whole class cri hurt word'
# 1	0.00	b'lunch'
# 1	0.00	b'hawaii decemb kick back miss'
# 1	0.00	b'hope nate notic edit sinc made icon'
# 1	0.00	b'hah thousand lie'
# 1	0.00	b'nah beaut way'
# 1	0.00	b'get see glow sea technic fallout play see'
# 1	0.00	b'hahaha thu sneak away log'
# 1	0.00	b'yep trash af im indonesia hbu'
# 1	0.00	b'say must chri elli'
# 1	0.00	b'remind need one'
# 1	0.00	b'harri niall harri born ik stupid wanna chang'
# 1	0.00	b'play al n score fuck night'
# 1	0.00	b''
# 1	0.00	b'boom date z'
# 1	0.00	b'that way see west ham shit small club london villa biggest brum'
# 1	0.00	b'deni vagina rli poor thing'
# 1	0.00	b'oh white rabbit cutest thing ever seen wait ador'
# 1	0.00	b'alway motiv'
# 1	0.00	b'haha kyle babi'
# 1	0.00	b'goood mooorn want sleep'
# 1	0.00	b'lose'
# 1	0.00	b''
# 1	0.00	b'meet harri need life'
# 1	0.00	b'one sleep til wed'
# 1	0.00	b''
# 1	0.00	b'kid insid want one'
# 1	0.00	b'sorri fuck eric think he funni'
# 1	0.00	b'pimpl forehead size volcano'
# 1	0.00	b'back done na mag miryenda'
# 1	0.00	b'get snowbal'
# 1	0.00	b'nd go expir next year dat mtn u realli like'
# 1	0.00	b'wanna go back time everyth still fine'
# 1	0.00	b'idk follow'
# 1	0.00	b'feel like relaps'
# 1	0.00	b'lol sorri ultor first hitter favor much'
# 1	0.00	b'finish mass effect yesterday dont know shoud start mass effect game'
# 1	0.00	b'bad would remind exercis miss need come back'
# 1	0.00	b'add kik ughtm'
# 1	0.00	b'come chill fire'
# 1	0.00	b'mont doa header'
# 1	0.00	b'ted speaker say stress good bodi anoth speaker introduc way avoid stress ted thought laboratori'
# 1	0.00	b'good morn lol realli fuckin dark gonna rain hard coupl minut'
# 1	0.00	b'far lfc fan make expert spot mental weak lack consist'
# 1	0.00	b'stuff happen'
# 1	0.00	b'indirag want judiciari commit govt polici want rbi commit know mani similar view'
# 1	0.00	b'progress stone transfer chelsea'
# 1	0.00	b'cours man nofx shit'
# 1	0.00	b'gz name'
# 1	0.00	b'guess sleep list thing today'
# 1	0.00	b'wanna loser like'
# 1	0.00	b'congratul friend graduat lose plot'
# 1	0.00	b'hah thousand lie'
# 1	0.00	b'go room bc'
# 1	0.00	b'final went drive tonight'
# 1	0.00	b'suppos ask buy album'
# 1	0.00	b'guess never realli identifi pharmaci'
# 1	0.00	b'charg speaker final got earlier today'
# 1	0.00	b''
# 1	0.00	b'text wanna meet get'
# 1	0.00	b'long'
# 1	0.00	b'friend never talk anyon'
# 1	0.00	b'yeah left one supposedli hurt bc right heart appar fine good luck'
# 1	0.00	b'niall follow fan still without follow'
# 1	0.00	b'need stress time'
# 1	0.00	b'could make song version instrument form sound epic beat alon'
# 1	0.00	b'think hard bed'
# 1	0.00	b'liker like fast'
# 1	0.00	b'u mean hide fot'
# 1	0.00	b'hurt read holiday work'
# 1	0.00	b'wow prize delight eye pick win burst sing mine feel divin'
# 1	0.00	b'must watch'
# 1	0.00	b'thought work season realli busi day ok deal weekend toilet break'
# 1	0.00	b'daddi af'
# 1	0.00	b'latest one'
# 1	0.00	b'e l f thank singer kyuhyun thank e l f'
# 1	0.00	b'one last long lol block alreadi must nice tweet hate'
# 1	0.00	b'go work come home bout take care home famili therein see'
# 1	0.00	b'dominiqu biggest fan like oh england get fan sign'
# 1	0.00	b'vote time pleas may poem'
# 1	0.00	b'confid confin u ur limit'
# 1	0.00	b'wish colorado'
# 1	0.00	b'add snapchat yall give name'
# 1	0.00	b'fell asleep like fall asleep two hour'
# 1	0.00	b'imma use next time'
# 1	0.00	b'ob v kino'
# 1	0.00	b'gone make tho posit day adult keep act like mom'
# 1	0.00	b'chicken caesar salad tad bland live'
# 1	0.00	b'first leg tour go well'
# 1	0.00	b'freedom hangout whoever want'
# 1	0.00	b'leo season'
# 1	0.00	b'send one pleas wont expos roast'
# 1	0.00	b'yeah lost call day'
# 1	0.00	b'member chanc'
# 1	0.00	b'miss babi'
# 1	0.00	b'live jonah jareddd'
# 1	0.00	b'last class morn two week break'
# 1	0.00	b'may find confus simpl wolf'
# 1	0.00	b'promot'
# 1	0.00	b'even real word'
# 1	0.00	b'could misread wors thing'
# 1	0.00	b'yup happen everywher peopl cant debat come name call'
# 1	0.00	b'need get work today ibiza'
# 1	0.00	b'mistak happen man long get play game happi'
# 1	0.00	b'one construct critic welcom'
# 1	0.00	b'ye alway selfish fuck'
# 1	0.00	b'man sing rain'
# 1	0.00	b'laguna see'
# 1	0.00	b'true quit whenev want'
# 1	0.00	b'famili hang feel festiv jamuna futur park'
# 1	0.00	b'miss'
# 1	0.00	b'spirit'
# 1	0.00	b'hii follow pleas like ask one thing dm'
# 1	0.00	b'im wear mine dj next fri'
# 1	0.00	b'alreadi'
# 1	0.00	b'gm meet preciou soft ladi real friend mizz preciou mani like'
# 1	0.00	b'la'
# 1	0.00	b'also mean imma go back twitter activ caus know everyon miss xd'
# 1	0.00	b'oh gina busi wait see hear xxx'
# 1	0.00	b'morn emma'
# 1	0.00	b'love make two heart one'
# 1	0.00	b'close enought'
# 1	0.00	b'bad boy'
# 1	0.00	b'salon bleach hair olaplex damag like'
# 1	0.00	b'teamwork right'
# 1	0.00	b'tweetup without book rest assur book'
# 1	0.00	b'get home wake'
# 1	0.00	b'okkk frend milt h break k bad'
# 1	0.00	b'got bed yet'
# 1	0.00	b'awww sige next time u know na punta kayo dun imma make sure na go din'
# 1	0.00	b'nooo didnt even know that actual type googl'
# 1	0.00	b'found prompt'
# 1	0.00	b'case facebook wall'
# 1	0.00	b'home alon'
# 1	0.00	b'wayward pine later'
# 1	0.00	b'far lfc fan make expert spot mental weak lack consist'
# 1	0.00	b'park get sunlight'
# 1	0.00	b'insecur tonight'
# 1	0.00	b'mom horror movi'
# 1	0.00	b'oh hell yeah expect text next tuesday'
# 1	0.00	b'match day bitchesss real madrid vs man shitti'
# 1	0.00	b'squash commit still make commit'
# 1	0.00	b'first love wanna fuck late night think got nut v look'
# 1	0.00	b'watch joe dirt'
# 1	0.00	b'tym prepar'
# 1	0.00	b'sleep need tri lay bed bore'
# 1	0.00	b'b call friend need'
# 1	0.00	b'dear person pleas studi embarrass urself entropi work w evolut'
# 1	0.00	b'anoth note found camden town work'
# 1	0.00	b'scoup like jren nuest'
# 1	0.00	b'neuer post onlin fix spray'
# 1	0.00	b'class today train friend'
# 1	0.00	b'one fall love choic chanc'
# 1	0.00	b'seen uni talent'
# 1	0.00	b'uff itna miss karhi thi ap'
# 1	0.00	b'money tell stori'
# 1	0.00	b'save live'
# 1	0.00	b'break shell'
# 1	0.00	b'truth'
# 1	0.00	b'still green tea blend flavor'
# 1	0.00	b'sometim'
# 1	0.00	b'sorri ran friend rough day tri stream saturday'
# 1	0.00	b'parti cancel'
# 1	0.00	b'make alyssa rub tummi'
# 1	0.00	b'ive email regard cours queri'
# 1	0.00	b'comput count'
# 1	0.00	b'sleep much want love bug made token never mind'
# 1	0.00	b'nuf teas alreadi show us alien everyday seem get closer see alien cousin'
# 1	0.00	b'show full epi avail onlin'
# 1	0.00	b'evolut'
# 1	0.00	b'love airport'
# 1	0.00	b'hah say sorri'
# 1	0.00	b''
# 1	0.00	b''
# 1	0.00	b'im go bed love hailey milk crai sxxx cl runway look'
# 1	0.00	b'feel someon share review work hard'
# 1	0.00	b'bad thing think weird face rad thank though'
# 1	0.00	b'make aliv make suffer make feel addict song alway sing karaok'
# 1	0.00	b'ltsw gooo'
# 1	0.00	b'threw phone wall'
# 1	0.00	b'giant balloon want one'
# 1	0.00	b'face time'
# 1	0.00	b'one look like need much care studi favourit later'
# 1	0.00	b''
# 1	0.00	b'actual lol'
# 1	0.00	b'carp diem mr nath'
# 1	0.00	b'long feel comfort im gonna wear want mother haha sound nice'
# 1	0.00	b'time parti'
# 1	0.00	b'haha know mess'
# 1	0.00	b'found song mention nylon gvb cd take unto other'
# 1	0.00	b'yah know good fake mah emot'
# 1	0.00	b'idk cant wait tonight panel peopl'
# 1	0.00	b'elf hbu'
# 1	0.00	b'ps took hope count'
# 1	0.00	b'rememb someon see feat charli puth wiz khalifa'
# 1	0.00	b'done today watch law order svu love sick'
# 1	0.00	b'lmao love berni'
# 1	0.00	b'ye think b stupid discuss abt wild card entri jst wait perform'
# 1	0.00	b'u transpar glass'
# 1	0.00	b'rang sick yesterday told back today better morn anyway day sunday'
# 1	0.00	b'ping watch tl like hawk'
# 1	0.00	b'ye hay'
# 1	0.00	b'cours cite academ paper feel arriv'
# 1	0.00	b'still awak'
# 1	0.00	b'true'
# 1	0.00	b'exactli'
# 1	0.00	b'peasant seat watch peasant team mind ahahha'
# 1	0.00	b'could say egg face'
# 0	1.00	b'soon tweet plant claw thigh traction zoom away'
# 0	1.00	b'use pri pv wish could reliv day becom nyc pv buy way commun nyc usa klm'
# 0	1.00	b'realli hot'
# 0	1.00	b'live fam bam cough'
# 0	1.00	b'sore alic'
# 0	1.00	b'funni mo'
# 0	1.00	b'someon explain'
# 0	1.00	b'hayee hayee patwari mam vision would say noth rather lil laugh'
# 0	1.00	b'ga'
# 0	1.00	b'awhhh ok ok see nalang class open hehe'
# 0	1.00	b'imagin would shatter dream let colleagu know sb'
# 0	1.00	b'nakakapikon yung nagbabasa ka ng blog comment info full peopl ask damn question answer post'
# 0	1.00	b'lead caus cancer children five'
# 0	1.00	b'hello info possibl interest jonatha close join beti great'
# 0	1.00	b'thank send premium write instrument howev dastardli swine stole envelop'
# 0	1.00	b'true doubt'
# 0	1.00	b'today job anoth fack extra mega care get bent socket pin'
# 0	1.00	b'huge bag present luke open back work'
# 0	1.00	b'pci mine'
# 0	1.00	b'tya mind refollow'
# 0	1.00	b'apolog avail australia'
# 0	1.00	b'get bin osx chrome voiceov'
# 0	1.00	b'night devo xxx'
# 0	1.00	b'unfollow unni'
# 0	1.00	b'new album come'
# 0	1.00	b'mention south africa mani time song time come south africa'
# 0	1.00	b'hate rememb dream love share'
# 0	1.00	b'friday dead'
# 0	1.00	b'look fun snapchat lilybutl'
# 0	1.00	b'back delhi'
# 0	1.00	b'fun'
# 0	1.00	b'know happen internet light connect drop thank kei'
# 0	1.00	b'hanaaa birthday ya allah sorri wish van jn tak tau happi birthday gorgeou'
# 0	1.00	b'faith'
# 0	1.00	b'last present receiv haha basta'
# 0	1.00	b'relat full lie'
# 0	1.00	b'dhi block twitter thank good time play fakmarey'
# 0	1.00	b'shop fun'
# 0	1.00	b'would like abl work full time stuff move consid take fulltim job'
# 0	1.00	b'girl quick'
# 0	1.00	b'mani nasti narrow mind peopl'
# 0	1.00	b'hello info possibl interest jonatha close join beti'
# 0	1.00	b'haha sound like fun game'
# 0	1.00	b'follow'
# 0	1.00	b'follow'
# 0	1.00	b'grandad realli well worri much'
# 0	1.00	b'lot peopl suggest still'
# 0	1.00	b'follback pl'
# 0	1.00	b'molli deserv much higher place'
# 0	1.00	b'wanna good time one hit date much ask'
# 0	1.00	b'hey christin moodi'
# 0	1.00	b'throwback'
# 0	1.00	b'pretti'
# 0	1.00	b'matt'
# 0	1.00	b'hello info possibl interest jonatha close join beti saludo'
# 0	1.00	b'hey someon text'
# 0	1.00	b'anoth dissapoint review'
# 0	1.00	b'hi harri sorri work mast area caus intermitt servic work complet'
# 0	1.00	b'look fun snapchat janniecam'
# 0	1.00	b'taxi servic second schedul blog post housework bust'
# 0	1.00	b'billi'
# 0	1.00	b'nsc mat tomorrow'
# 0	1.00	b'awhh see guy ram car'
# 0	1.00	b'ok reason voucher use onlin'
# 0	1.00	b'never give best thing take time weh'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'need new phone'
# 0	1.00	b'first two day kati summer back forth doctor suspect mening viral tonsil poorli girl'
# 0	1.00	b'happi birthday pleas come back singapor'
# 0	1.00	b'yeah look'
# 0	1.00	b'gosh cheaper malaysia worth ship'
# 0	1.00	b'guy nooo wow wow wow wow'
# 0	1.00	b'never dedic anyth smh lol'
# 0	1.00	b'hello info possibl interest jonatha he close beti'
# 0	1.00	b'develop releas good game school'
# 0	1.00	b'spoil'
# 0	1.00	b'fav chees give migrin'
# 0	1.00	b'oh think parcel come yodel hit follow dm track num chelsea'
# 0	1.00	b'oooouch poor pinki toe good thing work podiatrist wait morn go hurri morn'
# 0	1.00	b'gusto ko ng someon share order big'
# 0	1.00	b'ye hope next year'
# 0	1.00	b'look amaz think saw meadowhal day actual unfortun weekend work'
# 0	1.00	b'missin homeslic bday'
# 0	1.00	b'fav emoticon right emoticon'
# 0	1.00	b'see get eyebrow done prettylook wanna tri differ style'
# 0	1.00	b'aur ap bhi shamil ho'
# 0	1.00	b'hey sorri hear check servic statu page gen'
# 0	1.00	b'love'
# 0	1.00	b'ye'
# 0	1.00	b'biggest dream u follow brooo'
# 0	1.00	b'time last week rout lovebox share day new prod'
# 0	1.00	b'need job learn drive fricken health put back'
# 0	1.00	b'ehem haha ala yeke okay fun kk jumpa next time mayb'
# 0	1.00	b'shit bestfriend'
# 0	1.00	b'well tri someth keep mind bad thing alway'
# 0	1.00	b'oh build suit'
# 0	1.00	b'push client way host mayb better wait till next week'
# 0	1.00	b'lot good comic event seem kid part school program'
# 0	1.00	b'u guy togeth'
# 0	1.00	b'stori life haha look talk'
# 0	1.00	b'friend'
# 0	1.00	b'use flexibl'
# 0	1.00	b'justin come scotland'
# 0	1.00	b'ok write u everi week'
# 0	1.00	b'look like'
# 0	1.00	b'quot tweet'
# 0	1.00	b'listen album live franc'
# 0	1.00	b'time like style like'
# 0	1.00	b'account meant hit us lunch time'
# 0	1.00	b'hammer right look set day'
# 0	1.00	b'wonder happen earlier realiz leadership'
# 0	1.00	b'asian ummm mayb ur film child pornographi slutsham fake suicid ect'
# 0	1.00	b'good quit full time job last week find anoth one'
# 0	1.00	b'well cooki better worth'
# 0	1.00	b'keep forget area want visit next time xx'
# 0	1.00	b'funni'
# 0	1.00	b'fun osaka super junior would love watch comeback stage though'
# 0	1.00	b'backtrack hour time start actual util list'
# 0	1.00	b'pat jay'
# 0	1.00	b'give work old staff come polic later court look anoth job bye bye'
# 0	1.00	b'love warrior'
# 0	1.00	b'tomorrow'
# 0	1.00	b'whatev stil l young'
# 0	1.00	b'window'
# 0	1.00	b'well p page note thu far read twice'
# 0	1.00	b'dem free tix big bang concert'
# 0	1.00	b'carter deserv hate deserv singl corn chip deserv two corn chip'
# 0	1.00	b'ok w hahaahahahaha'
# 0	1.00	b'dare'
# 0	1.00	b'good morn twitter friend hope amaz day freakin tire need sleep'
# 0	1.00	b'wish twitter would support audio record would send yall snippet amaz'
# 0	1.00	b'master figur turn led gold doom'
# 0	1.00	b'oh allow vote teen choic award said area'
# 0	1.00	b'want icon selfi jack'
# 0	1.00	b'right tire good night alli love'
# 0	1.00	b'got excit micha rt fave tweet creep'
# 0	1.00	b'whose idea ave tripl busi lectur friday afternoon'
# 0	1.00	b'buy someth drank caus noth'
# 0	1.00	b'peopl r u'
# 0	1.00	b'wait love recuerda tanto bath'
# 0	1.00	b'much await excit go bore friday weekend'
# 0	1.00	b'best spectat sail uk bbc show highlight fli foil catamaran'
# 0	1.00	b'love babi sweet cinnamon best'
# 0	1.00	b'peng bestfriend'
# 0	1.00	b'kind dumb statement like moodsw like make tweet say hate termin diseas like wow uniqu'
# 0	1.00	b'pleas notic men'
# 0	1.00	b'watch us'
# 0	1.00	b'regret regret'
# 0	1.00	b'hi oh take look pleas chat us'
# 0	1.00	b'peopl wish birthday'
# 0	1.00	b'fave unfollow'
# 0	1.00	b'realli want visit iceland'
# 0	1.00	b'lrt bambam like soda meant'
# 0	1.00	b'cheer'
# 0	1.00	b'happi birthday be enjoy day beb love miss sooo muchi see soon sana'
# 0	1.00	b'cuti'
# 0	1.00	b'ask go bathroom realli enjoy show though'
# 0	1.00	b'naw deep dream novel hope invis page beast scuttl around worm track'
# 0	1.00	b'worri'
# 0	1.00	b'mine damnnn finee omaigoshhh'
# 0	1.00	b'care muslim'
# 0	1.00	b'jessica call quit power ab'
# 0	1.00	b'hope fun vidcon rlli bum couldnt go love sunshin'
# 0	1.00	b'last night good'
# 0	1.00	b'follow'
# 0	1.00	b'happi princess today sigh get work done x purpl princess edit'
# 0	1.00	b'think need year train beat record sia'
# 0	1.00	b'soul rest peac'
# 0	1.00	b'unfollow like peopl caus follow peopl difficult'
# 0	1.00	b'challeng though pleas check fb page entri rather substitut thank'
# 0	1.00	b'omg everi time would complain skin mom everyon get pimpl like although'
# 0	1.00	b'last full night greec opu inner pleasur'
# 0	1.00	b'ye bbq attend'
# 0	1.00	b'lol got split hard lol singl singl split collat spilt singl singl spilt singl split singl singl collat'
# 0	1.00	b'hope feel better jay'
# 0	1.00	b'ye mani time'
# 0	1.00	b'seolhyun isnt first ep she film drama'
# 0	1.00	b'fellow morn owl sure notic sun alreadi rise bit later sign winter come'
# 0	1.00	b'hot'
# 0	1.00	b'best get littl ladi need go wallpap mom realli cba today'
# 0	1.00	b'hi life'
# 0	1.00	b'mood whole day'
# 0	1.00	b'almost done park rec lol'
# 0	1.00	b'u come back'
# 0	1.00	b'first saw gnr open alic cooper famou parti backstag alic r slash'
# 0	1.00	b'tag sorri lot music prolli know half also'
# 0	1.00	b'love u fuck know'
# 0	1.00	b'hi love u'
# 0	1.00	b'go home blue back monday social action plan'
# 0	1.00	b'pro soccer play would cool'
# 0	1.00	b'ye thank depress weather forecast word rain mention sever time'
# 0	1.00	b'old one day'
# 0	1.00	b'girlll u hear abt possibl tsunami us west indi im island im afraid lol'
# 0	1.00	b'snap'
# 0	1.00	b'would love see w nick pick one waist tv time never work anyway'
# 0	1.00	b'hulk hogan news racial tirad thought couldnt stoop lower role thunder paradis'
# 0	1.00	b'facad democraci drop quickli'
# 0	1.00	b'bade fursat se usey banaya hai usey uppar waal ney afso hums dur hai wo'
# 0	1.00	b'oh realli saw gif post seen realli happi mayb peopl happi naruhina'
# 0	1.00	b'mcountdown begin place'
# 0	1.00	b'wow great usernam'
# 0	1.00	b'u chang u say chang tsk'
# 0	1.00	b'like join marin'
# 0	1.00	b'go kailan ba may tix ka'
# 0	1.00	b'nope best place get first amazon'
# 0	1.00	b'fwm'
# 0	1.00	b'thank lack time problem'
# 0	1.00	b'ur cat super nice cuddli suddenli scratch tri bite like trust anymor'
# 0	1.00	b'hit thumb'
# 0	1.00	b'follow back'
# 0	1.00	b'broken heart phase worri'
# 0	1.00	b'im get olli tweet notif'
# 0	1.00	b'way'
# 0	1.00	b'earth assum rain london like influenc overal warm dri past week continent europ'
# 0	1.00	b'r u sure u want b r u h bare surviv w tank top'
# 0	1.00	b'hmmm min get train current min away'
# 0	1.00	b'complet agre press'
# 0	1.00	b'hull support expect misser week'

# %% [markdown]
# # Part 6: Predict with your own tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 2.629788908713561
